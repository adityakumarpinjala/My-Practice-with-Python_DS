# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import os

# %%
os.getcwd()
os.chdir("D:\\Education\\Data Science\\Files\\Files1")

# %%
st=pd.read_csv("Store.csv",encoding="latin")

# %%
st.head(2)
st.shape
# Out:
# (9994, 21)

# %%
st.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
st[st['Region']=="East"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 23        24  US-2014-156909   7/17/2014   7/19/2014    Second Class
# 27        28  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 28        29  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 29        30  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 30        31  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 31        32  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 32        33  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 33        34  US-2012-150630   9/17/2012   9/21/2012  Standard Class
# 47        48  CA-2013-169194   6/21/2013   6/26/2013  Standard Class
# 48        49  CA-2013-169194   6/21/2013   6/26/2013  Standard Class
# 53        54  CA-2013-105816  12/12/2013  12/18/2013  Standard Class
# 54        55  CA-2013-105816  12/12/2013  12/18/2013  Standard Class
# 55        56  CA-2013-111682   6/18/2013   6/19/2013     First Class
# ...

# %%
st[st['Region']=="East"].shape
# Out:
# (2848, 21)

# %%
st[st['Region']=="East"]['Quantity'].reset_index(drop=True)
# Out:
# 0        2
# 1        7
# 2        2
# 3        3
# 4        2
# 5        6
# 6        6
# 7        2
# 8        3
# 9        2
# 10       7
# 11       5
# 12       6
# 13       5
# 14       5
# 15       2
# 16       2
# 17       4
# 18       1
# 19       1
# 20       7
# 21       2
# 22      14
# 23       2
# 24       3
# 25       6
# 26       3
# 27       4
# 28       6
# 29       9
#         ..
# 2818     1
# 2819     1
# 2820     3
# 2821     3
# 2822     1
# 2823     8
# 2824     2
# 2825     4
# 2826     3
# 2827     3
# 2828     3
# 2829     3
# 2830     5
# 2831     4
# 2832     7
# 2833     1
# 2834     3
# 2835     5
# 2836     4
# 2837     2
# 2838     2
# 2839     1
# 2840     1
# 2841     7
# 2842     5
# 2843     2
# 2844     7
# 2845     5
# 2846    10
# 2847     4
# Name: Quantity, Length: 2848, dtype: int64

# %%
st[st["Region"]=='East']['Quantity'].sum()
# Out:
# 10618

# %%
st[st["Region"]=='East'].sort_values('Sales',ascending=False).head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2623    2624  CA-2014-127180  10/23/2014  10/25/2014     First Class
# 4190    4191  CA-2014-166709  11/18/2014  11/23/2014  Standard Class
# 4277    4278  US-2013-107440   4/17/2013   4/21/2013  Standard Class
# 6425    6426  CA-2013-143714   5/24/2013   5/28/2013  Standard Class
# 6626    6627  CA-2011-145541  12/14/2011  12/21/2011  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 2623    TA-21385        Tom Ashbrook  Home Office  United States
# 4190    HL-15040        Hunter Lopez     Consumer  United States
# 4277    BS-11365        Bill Shonely    Corporate  United States
# 6425    CC-12370  Christopher Conant     Consumer  United States
# 6626    TB-21400    Tom Boeckenhauer     Consumer  United States
#
#                City    ...     Postal Code  Region       Product ID  \
# 2623  New York City    ...           10024    East  TEC-CO-10004722
# ...

# %%
st.query("Region=='South'").sort_values('Profit',ascending=False)['Customer ID'].head(10)
# Out:
# 509     CM-12385
# 8488    SE-20110
# 1454    MC-17425
# 5562    JE-15610
# 4093    KW-16435
# 994     MW-18235
# 2848    DM-13345
# 7583    KH-16690
# 9033    SC-20095
# 8312    BD-11500
# Name: Customer ID, dtype: object

# %%
st.groupby('Region',as_index=False).agg({"Quantity":np.mean})
# Out:
#     Region  Quantity
# 0  Central  3.779595
# 1     East  3.728230
# 2    South  3.832716
# 3     West  3.829535

# %%
st.groupby('Category',as_index=False).agg({"Sales":np.sum})
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
st.groupby('Category',as_index=False)[['Sales','Profit']].agg({'Sales':np.max,'Profit':np.sum})
# Out:
#           Category      Sales       Profit
# 0        Furniture   4416.174   18451.2728
# 1  Office Supplies   9892.740  122490.8008
# 2       Technology  22638.480  145454.9481

# %%
st.groupby('Segment',as_index=False).agg({'Discount':'mean'})
# Out:
#        Segment  Discount
# 0     Consumer  0.158141
# 1    Corporate  0.158228
# 2  Home Office  0.147128

# %%
st.groupby("Segment",as_index=False).agg({'Discount':np.sum}).rename(columns={'Discount':"DIS"})
# Out:
#        Segment     DIS
# 0     Consumer  820.91
# 1    Corporate  477.85
# 2  Home Office  262.33

# %%
st.groupby("Segment",as_index=False).agg({"Discount":np.mean}).rename(columns={'Discount':"DISC"}).sort_values("DISC",ascending=False)
# Out:
#        Segment      DISC
# 1    Corporate  0.158228
# 0     Consumer  0.158141
# 2  Home Office  0.147128

# %%
st.groupby("Segment",as_index=False).agg({"Profit":np.sum}).sort_values("Profit",ascending=False)
# Out:
#        Segment       Profit
# 0     Consumer  134119.2092
# 1    Corporate   91979.1340
# 2  Home Office   60298.6785

# %%
st["DR_CR"]=st["Sales"]/st["Sales"].mean()

# %%
st["Cost"]=st["Sales"]-st["Profit"]
st
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 2          3  CA-2013-138688   6/13/2013   6/17/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 5          6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 6          7  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 7          8  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 8          9  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 9         10  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 10        11  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 11        12  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 12        13  CA-2014-114412   4/16/2014   4/21/2014  Standard Class
# ...

# %%
def get_sum(x):
    return np.sum(x)

st[['Quantity','Profit','Sales']].apply(get_sum,axis=1)
# Out:
# 0        305.8736
# 1        954.5220
# 2         23.4914
# 3        579.5465
# 4         26.8844
# 5         70.0294
# 6         13.2456
# 7       1003.8672
# 8         27.2865
# 9        154.3700
# 10      1800.4932
# 11       983.7808
# 12        23.9952
# 13       543.5682
# 14       -50.0480
# 15         1.7280
# 16       685.1976
# 17        67.4900
# 18        13.0424
# 19       232.4910
# 20        34.1040
# 21        31.5196
# 22        83.0284
# 23        72.3524
# 24      1287.8949
# 25        17.8704
# 26       105.3441
# 27      1425.3778
# 28         4.5648
# 29       142.7250
#           ...
# 9964      20.8320
# 9965       8.3206
# 9966     168.2443
# 9967      63.2900
# 9968    1069.1710
# 9969      36.3475
# 9970     176.5576
# 9971     187.9750
# 9972     135.1722
# 9973     304.1560
# 9974      30.9232
# 9975      21.7728
# 9976     282.7820
# 9977      20.8600
# 9978      22.0576
# 9979     604.5872
# 9980     109.3348
# 9981      26.8890
# 9982      59.2732
# ...

# %%
st['prof']=(st["Profit"]>5000).map({True:"good",False:"Bad"})
st
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 2          3  CA-2013-138688   6/13/2013   6/17/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 5          6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 6          7  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 7          8  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 8          9  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 9         10  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 10        11  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 11        12  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 12        13  CA-2014-114412   4/16/2014   4/21/2014  Standard Class
# ...

# %%
st["Order Date"]=pd.to_datetime(st["Order Date"])
st.dtypes
st["Ship Date"]=pd.to_datetime(st["Ship Date"])
st.dtypes
st["DIFF"]=st["Ship Date"]-st["Order Date"]
st
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 5          6  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 6          7  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 7          8  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 8          9  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 9         10  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 10        11  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 11        12  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 12        13  CA-2014-114412 2014-04-16 2014-04-21  Standard Class
# ...

# %%
st.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country                   object
# City                      object
# State                     object
# Postal Code                int64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# DR_CR                    float64
# Cost                     float64
# prof                      object
# DIFF             timedelta64[ns]
# dtype: object

# %%
st[st["DIFF"]>"5 days"].shape[0]/st.shape[0]
# Out:
# 0.18230938563137883

# %%
st[st["DIFF"]>"5 days"].groupby("Category",as_index=False).agg({"DIFF":np.size})
# Out:
#           Category  DIFF
# 0        Furniture   365
# 1  Office Supplies  1131
# 2       Technology   326

# %%
st[st["DIFF"]> "5 days"].shape[0]
# Out:
# 1822

# %%
sd=pd.read_csv("Strings.csv")
sd.head(5)
# Out:
#    Age    Income_M Expenses
# 0   10  Rs 12000/-    8,000
# 1   30  Rs 45000/-   21,000
# 2   34  Rs 39000/-   20,000
# 3   16   Rs 6000/-    2,000
# 4   19  Rs 20000/-   10,000

# %%
sd["Income_M"]=sd["Income_M"].str.replace("Rs","")
sd["Income_M"]=sd["Income_M"].str.replace("/-","")
sd["Income_M"]=pd.to_numeric(sd["Income_M"])
sd["Income_M"].mean()
# Out:
# 36600.0

# %%
S_O=pd.read_csv("Sales_Oct.csv")
S_S=pd.read_csv("Sales_Sep.csv")

# %%
row_con=pd.concat([S_O,S_S])
row_con.shape
row_con.head()
# Out:
#   Cust_ID  Sales_Amount
# 0     CS1          1000
# 1     CS2           890
# 2     CS3           900
# 3     CS4           450
# 4     CS8           980

# %%
df1=DataFrame({"cust_id":[1,2,3,4,5],"prod":["Tele","Scoo","Auto","spea","Radio"]})
df2=DataFrame({"cust_ID":[2,3],"state":["Cali","Arka"]})

df3=pd.merge(df1,df2,how="inner",left_on="cust_id",right_on="cust_ID").drop("cust_id",axis=1)

print(df3)
# Out:
#    prod  cust_ID state
# 0  Scoo        2  Cali
# 1  Auto        3  Arka

# %%
def double(x):
    return 2*x

# %%
double(10)
# Out:
# 20
